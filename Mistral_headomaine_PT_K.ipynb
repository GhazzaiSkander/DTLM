# %% [markdown]
# <a href="https://colab.research.google.com/github/GhazzaiSkander/DTLM/blob/dtlm/Mistral_headomaine_PT_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/GhazzaiSkander/DTLM.git@dtlm#egg=dtlm
# Out:
# ...
#   Cloning https://github.com/GhazzaiSkander/DTLM.git (to revision dtlm) to /tmp/pip-install-gxm0ajfz/dtlm_4fc2f9d86cfa4dd6b22f3d9fde4bb12f
#   Running command git clone --filter=blob:none --quiet https://github.com/GhazzaiSkander/DTLM.git /tmp/pip-install-gxm0ajfz/dtlm_4fc2f9d86cfa4dd6b22f3d9fde4bb12f
#   Running command git checkout -b dtlm --track origin/dtlm
#   Switched to a new branch 'dtlm'
#   Branch 'dtlm' set up to track remote branch 'dtlm' from 'origin'.
#   Resolved https://github.com/GhazzaiSkander/DTLM.git to commit 4e8cbb74f4a92852746211e8380632838ba76c4b
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 21.6 MB/s eta 0:00:00
# ...

# %%
import os
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

client = MistralClient(api_key=api_key)
model = "mistral-tiny"

# %%
import pandas as pd

# %%
from dtlm import simple_transformation

# %%
import os
# List all files and directories in the current working directory
files_and_directories = os.listdir()

files = [item for item in files_and_directories if os.path.isfile(item) and ".txt"  in item]
nb_correct_instance=0
all_values=0
true_dataset=0
# Process each file in the list
datasets=[]
desired_format_list=[]
for file_name in files:
    first_values = []
    second_values = []
    with open(file_name, 'r', encoding='latin-1') as file:
        print(file_name)
        for line_number, line in enumerate(file):
            parts = line.strip().split('\t')  # Assuming tab-separated values
            if len(parts)>=3 :
              first_value= parts[0]
              second_value=parts[2]
              first_values.append(first_value)
              second_values.append(second_value)


    print("First values:",first_values)
    print("Second values:",second_values)
    print()
    first_values=list(first_values)
    second_values=list(second_values)
    df = pd.DataFrame({"input": first_values, "target": second_values})
    simple_transformation(df,"mistral-tiny",client)
    datasets.append(df)
# Out:
# funct_nmea_bearing.txt
# First values: ['$GPRMC,084752.000,A,5152.4175,N,00832.5083,W,11.90,62.01,231110,,*12', '$GPRMC,155123.000,A,4043.8432,N,07359.7653,W,0.15,83.25,200407,,*28', '$GPRMC,235947.000,V,0000.0000,N,00000.0000,E,,,041299,,*1D', '$GPRMC,092204.999,A,4250.5589,S,14718.5084,E,0.00,89.68,211200,,*25', '$GPRMC,155123.000,A,4043.8432,N,07359.7653,W,0.15,83.25,200407,,*28']
# Second values: ['62.01', '83.25', '0', '89.68', '83.25']
# Dropdown(description='Select Column:', options=('input', 'target'), value='input')
# Text(value='', description='Describe Transformation:', placeholder='e.g., Convert C to F')
# Text(value='', description='Input:')
# Text(value='', description='Output:')
# Button(description='Add Example Pair', style=ButtonStyle())
# Button(description='Process Examples', style=ButtonStyle())
# Output()
# funct_comp_address_secondaryline.txt
# ...
